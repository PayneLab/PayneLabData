# %% [markdown]
# # Use Case 5: Gene set enrichment analysis

# %% [markdown]
# ## Step 1: Importing packages and setting up your notebook.
#
# We start the notebook by importing the standard packages for data science. These are useful for playing data in dataframes and for plotting the results.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import gseapy as gp
from gseapy.plot import barplot, dotplot

# %% [markdown]
# Our cancer data and a variety of accessory functions are provided in the CPTAC package.

# %%
import CPTAC
# Out:
# Loading Dictionary...
# Loading Clinical Data...
# Loading Proteomics Data...
# Loading Transcriptomics Data...
# Loading CNA Data...
# Loading Phosphoproteomics Data...
# Loading Somatic Mutation Data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter CPTAC.embargo() to open the webpage for more details.

# %% [markdown]
# ## Step 2: Getting data
#
# We begin by retrieving the clinical and proteomics dataframes utilizing the <code>CPTAC.get_clinical()</code> and <code>CPTAC.get_proteomics()</code> functions.

# %%
clinical = CPTAC.get_clinical()
proteomics = CPTAC.get_proteomics()

# %% [markdown]
# ## Step 3: Merging dataframes
#
# For this example we will be separating the protein abudance based on the clinical MSI (microsatellite instability). We first combine the MSI information into the proteomics dataframe utilizing the <code>CPTAC.compare_clinical()</code> function.

# %%
for i in range(0, len(CPTAC.get_clinical().columns)):
    print(CPTAC.get_clinical().columns[i])
# Out:
# Proteomics_Participant_ID
# Proteomics_TMT_batch
# Proteomics_TMT_plex
# Proteomics_TMT_channel
# Proteomics_Parent_Sample_IDs
# Proteomics_Aliquot_ID
# Proteomics_Tumor_Normal
# Proteomics_OCT
# Country
# Histologic_Grade_FIGO
# Myometrial_invasion_Specify
# Histologic_type
# Treatment_naive
# Tumor_purity
# Case_quality
# Path_Stage_Primary_Tumor-pT
# Path_Stage_Reg_Lymph_Nodes-pN
# Clin_Stage_Dist_Mets-cM
# Path_Stage_Dist_Mets-pM
# tumor_Stage-Pathological
# FIGO_stage
# LVSI
# BMI
# Age
# Diabetes
# Race
# Ethnicity
# Gender
# Tumor_Site
# Tumor_Site_Other
# Tumor_Focality
# Tumor_Size_cm
# Estrogen_Receptor
# Estrogen_Receptor_%
# Progesterone_Receptor
# Progesterone_Receptor_%
# MLH1
# MLH2
# MSH6
# PMS2
# p53
# Other_IHC_specify
# MLH1_Promoter_Hypermethylation
# Num_full_term_pregnancies
# EPIC_Bcells
# EPIC_CAFs
# EPIC_CD4_Tcells
# EPIC_CD8_Tcells
# EPIC_Endothelial
# EPIC_Macrophages
# EPIC_NKcells
# EPIC_otherCells
# CIBERSORT_B _cells _naive
# CIBERSORT_B _cells _memory
# CIBERSORT_Plasma _cells
# CIBERSORT_T _cells _CD8
# CIBERSORT_T _cells _CD4 _naive
# CIBERSORT_T _cells _CD4 _memory _resting
# CIBERSORT_T _cells _CD4 _memory _activated
# CIBERSORT_T _cells _follicular _helper
# CIBERSORT_T _cells _regulatory _(Tregs)
# CIBERSORT_T _cells _gamma _delta
# CIBERSORT_NK _cells _resting
# CIBERSORT_NK _cells _activated
# CIBERSORT_Monocytes
# CIBERSORT_Macrophages _M0
# CIBERSORT_Macrophages _M1
# CIBERSORT_Macrophages _M2
# CIBERSORT_Dendritic _cells _resting
# CIBERSORT_Dendritic _cells _activated
# CIBERSORT_Mast _cells _resting
# CIBERSORT_Mast _cells _activated
# CIBERSORT_Eosinophils
# CIBERSORT_Neutrophils
# CIBERSORT_Absolute _score
# ESTIMATE_StromalScore
# ESTIMATE_ImmuneScore
# ESTIMATE_ESTIMATEScore
# Stemness_score
# Pathway_activity_EGFR
# Pathway_activity_Hypoxia
# Pathway_activity_JAK.STAT
# Pathway_activity_MAPK
# Pathway_activity_NFkB
# Pathway_activity_PI3K
# Pathway_activity_TGFb
# Pathway_activity_TNFa
# Pathway_activity_Trail
# Pathway_activity_VEGF
# Pathway_activity_p53
# TP53_ATM
# TP53_CHEK2
# TP53_MDM4
# TP53_RPS6KA3
# TP53_TP53
# TP53_pathway
# PI3K_AKT1
# PI3K_AKT2
# PI3K_AKT3
# PI3K_DEPDC5
# PI3K_DEPTOR
# PI3K_INPP4B
# PI3K_MAPKAP1
# PI3K_MLST8
# PI3K_MTOR
# PI3K_NPRL2
# PI3K_NPRL3
# PI3K_PDK1
# PI3K_PIK3CA
# PI3K_PIK3CB
# PI3K_PIK3R1
# PI3K_PIK3R2
# PI3K_PPP2R1A
# PI3K_PTEN
# PI3K_RHEB
# PI3K_RICTOR
# PI3K_RPS6
# PI3K_RPS6KB1
# PI3K_RPTOR
# PI3K_STK11
# PI3K_TSC1
# PI3K_TSC2
# PI3K_pathway
# HRD_BRCA1
# HRD_BRCA2
# HRD_BRCA1_or_BRCA2
# Log2_SNP
# Log2_INDEL
# Mutation_signature_C>A
# Mutation_signature_C>G
# Mutation_signature_C>T
# Mutation_signature_T>C
# Mutation_signature_T>A
# Mutation_signature_T>G
# CNV_clustering
# Purity_Immune
# Purity_Cancer
# Purity_Stroma
# MSI_status
# POLE_subtype
# JAK1_MS_INDEL
# JAK1_Mutation
# WXS_normal_sample_type
# WXS_normal_filename
# WXS_normal_UUID
# WXS_tumor_sample_type
# WXS_tumor_filename
# WXS_tumor_UUID
# WGS_normal_sample_type
# WGS_normal_UUID
# WGS_tumor_sample_type
# WGS_tumor_UUID
# RNAseq_R1_sample_type
# RNAseq_R1_filename
# RNAseq_R1_UUID
# RNAseq_R2_sample_type
# RNAseq_R2_filename
# RNAseq_R2_UUID
# miRNAseq_sample_type
# miRNAseq_UUID
# Methylation_available
# Methylation_quality

# %%
msiProt = CPTAC.compare_clinical(proteomics, 'MSI_status')

# %% [markdown]
# ## Step 4: Organizing the data
#
# We then separate the proteomics into two groups, based on whether the patient is MSI-H (microsatellite instability high) or MSS (microsatellite stable, which we term also as MSI-normal for easy conceptualization of comparison).

# %%
#Retrieve boolean array of true values
high = msiProt['MSI_status'] == "MSI-H"
normal = msiProt['MSI_status'] != "MSI-H"
#Use boolean array to select for appropriate patients
high_MSI = msiProt[high]
normal_MSI = msiProt[normal]

# %% [markdown]
# ## Step 5: Perform statistical tests
#
# Next, we find which genes that are upregulated in each partition using Welch's t-test (a variation on the two sample t-test due to different variances between the two groups) to compare the MSI-high individuals with the MSS or MSI-normal individuals for each gene.

# %%
#Create array variables to hold the significant genes for each partition
high_MSI_genes = []
normal_MSI_genes = []
#Grab the genes of interest, ignoring the MSI column in the dataframe
genes = high_MSI.columns[1:]
#Correct alpha level for multiple testing by dividing the standard .05 by the number of genes to be analyzed
threshold = .05 / len(genes)
#Perform Welch's t-test(different variances) on each gene between the two groups
for gene in genes:
    high_MSI_gene_abundance = high_MSI[gene]
    normal_MSI_gene_abundance = normal_MSI[gene]
    pvalue = stats.ttest_ind(high_MSI_gene_abundance, normal_MSI_gene_abundance, equal_var = False, nan_policy='omit').pvalue
    #If the P-value is significant, determine which partition is more highly expressed
    if pvalue < threshold:
        if high_MSI_gene_abundance.mean() > normal_MSI_gene_abundance.mean():
            high_MSI_genes.append(gene)
        elif normal_MSI_gene_abundance.mean() > high_MSI_gene_abundance.mean():
            normal_MSI_genes.append(gene)
#Optional check of number of genes in each partition
print("MSI High Genes:", len(high_MSI_genes))
print("MSI Normal Genes:", len(normal_MSI_genes))
# Out:
# MSI High Genes: 191
# MSI Normal Genes: 619

# %% [markdown]
# ## Step 6: Gene set enrichment analysis
#
# We then use the genes that are up-regulated in these partitions to perform a Gene Set Enrichment Analysis using the <code>gp.enrichr()</code> function (<code>gp</code> being the specified abbreviation for the imported gseapy package).

# %%
MSI_high_enr = gp.enrichr(gene_list = high_MSI_genes, description='MSI High partition', gene_sets='KEGG_2016', outdir='test/enrichr_kegg',cutoff=.5)
MSI_normal_enr = gp.enrichr(gene_list = normal_MSI_genes, description='MSI Normal partition', gene_sets='KEGG_2016', outdir='test/enrichr_kegg',cutoff=.5)

# %% [markdown]
# We can view the data as a table by using the <code>obj.res2d</code> command (<code>obj</code> being the variable name specified in the previous step). The Gene Set Enrichment Analysis returns a list of pathways the genes provided are involved in, based on a significant adjusted P-value.

# %%
MSI_high_enr.res2d
# Out:
#                                                   Term  Overlap       P-value  \
# 0          Pyrimidine metabolism_Homo sapiens_hsa00240    9/105  7.468436e-07
# 1              Purine metabolism_Homo sapiens_hsa00230    9/176  5.044195e-05
# 2             Metabolic pathways_Homo sapiens_hsa01100  26/1239  1.310670e-04
# 3    Terpenoid backbone biosynthesis_Homo sapiens_h...     4/22  5.153049e-05
# 4                 Tight junction_Homo sapiens_hsa04530    7/139  3.833030e-04
# 5          p53 signaling pathway_Homo sapiens_hsa04115     5/69  5.164306e-04
# 6            Pyruvate metabolism_Homo sapiens_hsa00620     4/40  5.629646e-04
# 7                     Peroxisome_Homo sapiens_hsa04146     5/83  1.198261e-03
# 8    Progesterone-mediated oocyte maturation_Homo s...     5/98  2.498832e-03
# 9                       Ribosome_Homo sapiens_hsa03010    6/137  2.049724e-03
# 10                Oocyte meiosis_Homo sapiens_hsa04114    5/123  6.572062e-03
# 122  Cysteine and methionine metabolism_Homo sapien...     1/45  3.509810e-01
# 123        Propanoate metabolism_Homo sapiens_hsa00640     1/32  2.645759e-01
# 124  Glyoxylate and dicarboxylate metabolism_Homo s...     1/28  2.357554e-01
# 125         Butanoate metabolism_Homo sapiens_hsa00650     1/28  2.357554e-01
# 126  alpha-Linolenic acid metabolism_Homo sapiens_h...     1/25  2.134052e-01
# 127  Proximal tubule bicarbonate reclamation_Homo s...     1/23  1.981451e-01
# 128  Biosynthesis of unsaturated fatty acids_Homo s...     1/23  1.981451e-01
# 129  Pantothenate and CoA biosynthesis_Homo sapiens...     1/18  1.586940e-01
# 130   Non-homologous end-joining_Homo sapiens_hsa03450     1/13  1.173127e-01
# 131  Synthesis and degradation of ketone bodies_Hom...     1/10  9.151839e-02
#
#      Adjusted P-value  Old P-value  Old Adjusted P-value   Z-score  \
# 0            0.000099     0.000010              0.001351 -1.789382
# 1            0.002267     0.000443              0.019483 -1.751613
# 2            0.004325     0.004611              0.076077 -1.937089
# 3            0.002267     0.000268              0.017671 -1.604807
# 4            0.010119     0.002132              0.047287 -1.601917
# 5            0.010616     0.002149              0.047287 -1.598815
# 6            0.010616     0.002052              0.047287 -1.600895
# 7            0.019771     0.004566              0.076077 -1.506403
# 8            0.032985     0.008831              0.116574 -1.688510
# 9            0.030063     0.008428              0.116574 -1.552216
# 10           0.064080     0.021006              0.186978 -1.565827
# 11           0.051560     0.012540              0.137940 -1.388532
# 12           0.064080     0.021645              0.186978 -1.404561
# 13           0.053410     0.012199              0.137940 -1.276472
# 14           0.116260     0.045947              0.336943 -1.327546
# 15           0.143334     0.051262              0.352179 -1.384366
# 16           0.087188     0.025003              0.194144 -1.148586
# 17           0.153501     0.064366              0.369403 -1.360715
# 18           0.074964     0.020167              0.186978 -1.014629
# 19           0.165229     0.055658              0.352179 -1.258161
# 20           0.179009     0.074057              0.374225 -1.229230
# 21           0.222381     0.118824              0.522824 -1.295512
# 22           0.179009     0.069992              0.369557 -0.991416
# 23           0.308907     0.138194              0.552778 -1.076086
# 24           0.257569     0.110787              0.504706 -0.945583
# 25           0.369802     0.206750              0.664000 -0.943012
# 26           0.354595     0.173753              0.637093 -0.832567
# 27           0.394835     0.205149              0.664000 -0.845106
# 28           0.369802     0.189278              0.664000 -0.803205
# 29           0.455383     0.261081              0.703545 -0.881721
# ..                ...          ...                   ...       ...
# 102          0.719762     0.573601              0.866035  1.126651
# 103          0.719762     0.578938              0.866035  1.232950
# 104          0.713451     0.557183              0.866035  1.169510
# 105          0.705394     0.534318              0.866035  1.113687
# 106          0.705394     0.534318              0.866035  1.119651
# 107          0.705394     0.516406              0.866035  1.091532
# 108          0.705394     0.485028              0.866035  1.041524
# 109          0.705432     0.545893              0.866035  1.265095
# 110          0.087188     0.022664              0.186978  0.227272
# 111          0.705394     0.504088              0.866035  1.153832
# 112          0.705394     0.458484              0.866035  1.058916
# 113          0.705394     0.516406              0.866035  1.251750
# 114          0.705394     0.437692              0.866035  1.058522
# 115          0.705394     0.528421              0.866035  1.325148
# 116          0.705394     0.504088              0.866035  1.249403
# 117          0.705394     0.478515              0.866035  1.196639
# 118          0.705394     0.471921              0.866035  1.181719
# 119          0.705394     0.458484              0.866035  1.165071
# 120          0.705394     0.478515              0.866035  1.228541
# 121          0.705394     0.451639              0.866035  1.176232
# 122          0.705394     0.437692              0.866035  1.261017
# 123          0.623643     0.338088              0.826438  1.786994
# 124          0.576291     0.304069              0.757305  2.009524
# 125          0.576291     0.304069              0.757305  2.032104
# 126          0.550436     0.277426              0.718044  2.143158
# 127          0.523103     0.259106              0.703545  2.161426
# 128          0.523103     0.259106              0.703545  2.214917
# 129          0.455383     0.211273              0.664000  2.992620
# 130          0.397058     0.160389              0.604894  3.449274
# 131          0.354595     0.128314              0.529296  3.931775
#
#      Combined Score                                              Genes  \
# 0         25.243550  NME1-NME2;NT5C3A;DTYMK;RRM1;RRM2;PNP;POLE;DCK;...
# 1         17.331667   NME1-NME2;NT5C3A;RRM1;RRM2;PNP;PKM;ADSS;POLE;DCK
# 2         17.317195  IDI1;DTYMK;HSD17B4;UAP1;UQCR11;NME1-NME2;LDHA;...
# 3         15.844797                              IDI1;HMGCS1;PDSS2;MVD
# 4         12.601776            OCLN;PPP2R1B;CTNNA1;CGN;TJP3;LLGL2;TJP2
# 5         12.100742                        CCNB1;RRM2;CASP3;CDK1;GTSE1
# 6         11.978364                                  LDHA;PKM;ME2;PCK2
# 7         10.133398                     SCP2;ACOX1;HSD17B4;HACL1;DECR2
# 8         10.117436                  CCNA2;HSP90AA1;CCNB1;RPS6KA1;CDK1
# 9          9.608293                RPS7;RPL22L1;RPS3A;RPS2;MRPL24;RPL9
# 10         7.868168                  CCNB1;PPP2R1B;RPS6KA1;CDK1;PPP1CA
# 11         7.567387                               SCP2;CPT2;ACOX1;PCK2
# 12         7.010672                        CCNA2;CCNB1;CDK1;BUB1B;MCM6
# 13         6.800596                                     FEN1;MCM6;POLE
# 14         5.501824                 PPP2R1B;RASSF6;CTNNA1;LLGL2;PPP1CA
# 15         5.372640                          RPS6KA1;GFPT1;PCK2;PPP1CA
# 16         5.198878                                 GFPT1;GNPNAT1;UAP1
# 17         5.117808                DNAJC3;HSP90AA1;HYOU1;UBE2G1;SEC23B
# 18         4.835211                                  PSMA3;PSMA4;PSME3
# 19         4.578075                                      LDHA;PKM;PCK2
# 20         4.261967                            CCNA2;PPP2R1B;EEF2;PCK2
# 21         3.956440                           CCNA2;PKM;CASP3;CDK1;REL
# 22         3.355196                                     DSP;JUP;CTNNA1
# 23         2.823146                                      LDHA;PKM;PCK2
# 24         2.715692                               PPP2R1B;CSTF3;PPP1CA
# 25         2.156522                            CASP3;C1QBP;CDK1;PPP1CA
# 26         1.968382                                        PKM;PGP;ME2
# 27         1.837685                                 AP1G2;DNASE2;AP1M2
# 28         1.820603                                   OCLN;CTNNA1;VAV2
# 29         1.671653                                  CASP6;CASP3;LMNB1
# ..              ...                                                ...
# 102       -0.839178                                             PPP1CA
# 103       -0.905355                                              CASP3
# 104       -0.909636                                               CLPB
# 105       -0.918882                                            RPS6KA1
# 106       -0.923802                                            PPP2R1B
# 107       -0.942384                                                JUP
# 108       -0.972083                                             CTNNA1
# 109       -1.013253                                              CASP3
# 110       -1.020288                                       SCP2;HSD17B4
# 111       -1.027330                                              CASP3
# 112       -1.054433                                                PKM
# 113       -1.080709                                           HSP90AA1
# 114       -1.108297                                               TAF9
# 115       -1.109887                                              CASP3
# 116       -1.112423                                               OCLN
# 117       -1.134840                                               TJP2
# 118       -1.138895                                           ALDH18A1
# 119       -1.160138                                             HMGCS1
# 120       -1.165094                                              CASP3
# 121       -1.190817                                               POLE
# 122       -1.320314                                               LDHA
# 123       -2.376035                                               LDHA
# 124       -2.903682                                                PGP
# 125       -2.936310                                             HMGCS1
# 126       -3.310241                                              ACOX1
# 127       -3.498821                                               PCK2
# 128       -3.585410                                              ACOX1
# 129       -5.508746                                               PPCS
# 130       -7.391492                                               FEN1
# 131       -9.401721                                             HMGCS1
#
#       Gene_set
# 0    KEGG_2016
# 1    KEGG_2016
# 2    KEGG_2016
# 3    KEGG_2016
# 4    KEGG_2016
# 5    KEGG_2016
# 6    KEGG_2016
# 7    KEGG_2016
# 8    KEGG_2016
# 9    KEGG_2016
# 10   KEGG_2016
# 11   KEGG_2016
# 12   KEGG_2016
# 13   KEGG_2016
# 14   KEGG_2016
# 15   KEGG_2016
# 16   KEGG_2016
# 17   KEGG_2016
# 18   KEGG_2016
# 19   KEGG_2016
# 20   KEGG_2016
# 21   KEGG_2016
# 22   KEGG_2016
# 23   KEGG_2016
# 24   KEGG_2016
# 25   KEGG_2016
# 26   KEGG_2016
# 27   KEGG_2016
# 28   KEGG_2016
# 29   KEGG_2016
# ..         ...
# 102  KEGG_2016
# 103  KEGG_2016
# 104  KEGG_2016
# 105  KEGG_2016
# 106  KEGG_2016
# 107  KEGG_2016
# 108  KEGG_2016
# 109  KEGG_2016
# 110  KEGG_2016
# 111  KEGG_2016
# 112  KEGG_2016
# 113  KEGG_2016
# 114  KEGG_2016
# 115  KEGG_2016
# 116  KEGG_2016
# 117  KEGG_2016
# 118  KEGG_2016
# 119  KEGG_2016
# 120  KEGG_2016
# 121  KEGG_2016
# 122  KEGG_2016
# 123  KEGG_2016
# 124  KEGG_2016
# 125  KEGG_2016
# 126  KEGG_2016
# 127  KEGG_2016
# 128  KEGG_2016
# 129  KEGG_2016
# 130  KEGG_2016
# 131  KEGG_2016
#
# [132 rows x 10 columns]

# %%
MSI_normal_enr.res2d
# Out:
#                                                   Term Overlap       P-value  \
# 0                 Focal adhesion_Homo sapiens_hsa04510  37/202  1.804666e-18
# 1    Complement and coagulation cascades_Homo sapie...   23/79  1.238481e-16
# 2        Proteoglycans in cancer_Homo sapiens_hsa05205  30/203  1.155107e-12
# 3                 Prion diseases_Homo sapiens_hsa05020   10/35  6.846497e-08
# 4    Bacterial invasion of epithelial cells_Homo sa...   14/78  1.054044e-07
# 5    Regulation of actin cytoskeleton_Homo sapiens_...  22/214  9.008260e-07
# 6         24.776790  WNT2B;ROCK1;ROCK2;LAMA4;PTEN;FGF2;GNG7;SUFU;AK...
# 7         24.541726  GUCY1A2;MEF2C;PPP1R12A;ROCK1;IRS1;ROCK2;PRKCE;...
# 8         19.097205  IQSEC1;CAV2;CAV1;ARPC1A;WIPF3;SNX12;PARD6G;AGA...
# 9         17.646331  GUCY1A2;MEF2C;PPP1R12A;ROCK1;ROCK2;CACNA2D1;IT...
# 10        17.526794  GUCY1A2;PPP1R12A;ROCK1;ROCK2;PRKCE;ITPR1;PRKCA...
# 11        16.648679  TNXB;IRS1;LAMA4;PTEN;FGF2;THBS3;RPTOR;GNG7;AKT...
# 12        13.839549  TNXB;VWF;COL4A1;LAMB2;LAMA4;COL6A2;COL6A1;COL6...
# 13        13.359240  CREBBP;WNT2B;ROCK2;SERPINF1;PRKCA;NFATC4;MAPK1...
# 14        12.267839  PDGFRB;MEF2C;CACNA2D1;SRF;PRKCA;FGF2;STK3;MAPK...
# 15        11.938262  CPA3;COL18A1;COL15A1;MME;COL4A1;COL14A1;ELN;CO...
# 16        11.520368  HDAC4;NOTCH2;PDGFRB;CREBBP;TNXB;ABCB1;ROCK1;IR...
# 17        11.046855  GUCY1A2;PPP1R12A;VWF;ROCK1;ROCK2;AKT3;ITPR1;TL...
# 18        10.129123  MAPK10;ROCK1;ROCK2;ARPC1A;ABL1;ITGA5;DOCK1;VCL...
# 19         9.202057  GNAO1;CREBBP;WNT2B;DVL2;DVL3;MITF;PRKCA;CAMK2G...
# 20         8.197937  CACNB3;DES;SGCD;TPM4;SGCB;CACNA2D1;LMNA;DMD;ITGA5
# 21         8.127642  MAPK10;STAT5B;AKT3;ABL1;GAB1;PRKCA;SOS1;CAMK2G...
# 22         7.353186  CACNB3;DES;SGCD;TPM4;SGCB;CACNA2D1;LMNA;DMD;ITGA5
# 23         7.319128  MAPK10;GNAO1;MAOB;MAOA;GNG7;AKT3;ITPR1;PRKCA;P...
# 24         7.203342  TJP1;PDGFRB;GUCY1A2;TUBB2B;ITPR1;PRKCA;SOS1;PR...
# 25         7.131625                       CPA3;ENPEP;MME;CMA1;PRCP;AGT
# 26         6.624678  GSN;CFL2;PRKCE;AKT3;ARPC1A;PRKCA;AMPH;PIP5K1C;...
# 27         6.298436  GNAO1;GUCY1A2;GNG7;ITPR1;PRKCA;GNG11;CAMK2G;PR...
# 28         5.940585       CACNB3;DES;SGCD;SGCB;CACNA2D1;LMNA;DMD;ITGA5
# 29         5.602325  ITPKB;INPP5A;ITPR1;PTEN;PRKCA;PIP4K2B;PIP5K1C;...
# ..              ...                                                ...
# 183       -4.370597                                               PFKM
# 184       -4.435769                              AKT3;PRKCA;SOS1;MAPK3
# 185       -4.440401                                              MAPK3
# 186       -4.536339                           MAPK10;TAB3;MAP3K7;MAPK3
# 187       -4.569051                                         PRKCA;DNM1
# 188       -5.008388                                               AOC3
# 189       -5.050387                           SETD1B;SETD7;SETMAR;AASS
# 190       -5.271792                                        ABCB1;ABCA8
# 191       -5.287863                                        DAPK3;MAPK3
# 192       -5.292360                                                HYI
# 193       -5.745673                                   GSTM2;GPX3;GSTM5
# 194       -5.805762                                  MAOB;MAOA;L3HYPDH
# 195       -5.808439                                     LRP1;HGF;THBS3
# 196       -5.857964                              WNT2B;RAB23;SUFU;WNT4
# 197       -6.577775                              MAOB;MAOA;HAAO;CYP1B1
# 198       -6.754296                                                RGN
# 199       -6.909111                               AOC3;MAOB;MAOA;SARDH
# 200       -7.184552                                        LAMA4;PRKCA
# 201       -7.290414                                   IRS1;PRKCA;MAPK3
# 202       -7.960277                                              APOA4
# 203       -8.652236                                  NOTCH2;SOS1;MAPK3
# 204       -8.803275                                           RGN;PFKM
# 205       -9.573731                                     AOC3;MAOB;MAOA
# 206      -10.648616                                        BST1;NMNAT3
# 207      -11.253503                                              PANK4
# 208      -12.825736                                             MAN2C1
# 209      -12.919532                                                CA3
# 210      -14.726621                                          PMS2;MLH1
# 211      -14.821564                                          MAOB;MAOA
# 212      -15.846813                                     AOC3;MAOB;MAOA
#
#       Gene_set
# 0    KEGG_2016
# 1    KEGG_2016
# 2    KEGG_2016
# 3    KEGG_2016
# 4    KEGG_2016
# 5    KEGG_2016
# 6    KEGG_2016
# 7    KEGG_2016
# 8    KEGG_2016
# 9    KEGG_2016
# 10   KEGG_2016
# 11   KEGG_2016
# 12   KEGG_2016
# 13   KEGG_2016
# 14   KEGG_2016
# 15   KEGG_2016
# 16   KEGG_2016
# 17   KEGG_2016
# 18   KEGG_2016
# 19   KEGG_2016
# 20   KEGG_2016
# 21   KEGG_2016
# 22   KEGG_2016
# 23   KEGG_2016
# 24   KEGG_2016
# 25   KEGG_2016
# 26   KEGG_2016
# 27   KEGG_2016
# 28   KEGG_2016
# 29   KEGG_2016
# ..         ...
# 183  KEGG_2016
# 184  KEGG_2016
# 185  KEGG_2016
# 186  KEGG_2016
# 187  KEGG_2016
# 188  KEGG_2016
# 189  KEGG_2016
# 190  KEGG_2016
# 191  KEGG_2016
# 192  KEGG_2016
# 193  KEGG_2016
# 194  KEGG_2016
# 195  KEGG_2016
# 196  KEGG_2016
# 197  KEGG_2016
# 198  KEGG_2016
# 199  KEGG_2016
# 200  KEGG_2016
# 201  KEGG_2016
# 202  KEGG_2016
# 203  KEGG_2016
# 204  KEGG_2016
# 205  KEGG_2016
# 206  KEGG_2016
# 207  KEGG_2016
# 208  KEGG_2016
# 209  KEGG_2016
# 210  KEGG_2016
# 211  KEGG_2016
# 212  KEGG_2016
#
# [213 rows x 10 columns]

# %% [markdown]
# ## Step 7: Plot the p-values
#
# We can better visualize these tables and the significant pathways detected through the gseapy imported <code>barplot()</code> function, which takes an enrichr table and a title as parameters.

# %%
barplot(MSI_high_enr.res2d,title="MSI High KEGG_2016")

# %%
barplot(MSI_normal_enr.res2d,title="MSI Normal KEGG_2016")

# %% [markdown]
# ## Discussion
#
# When comparing these barplots, we can observe the MSI-high group has less pathways expressed at a less significant adjusted P-value than the MSI-normal group. This makes sense when we consider that MSI-high (microsatellite instability high) individuals have a less stable genome, thus resulting in less functional genes and less functional pathways, correlating with a high probability of cancer.
